# %%
import pandas as pd
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
from xgboost import XGBClassifier

# %%
train = pd.read_csv('data/train_dropped_290_with_nans.csv')
test = pd.read_csv('data/test_dropped_290_with_nans.csv')

print(train.shape, test.shape)
# Out:
# (2838, 294) (939, 293)

# %%
to_drop=[]
for i,j in enumerate(test.isna().sum()):
    print(list(test.columns)[i],j/939)
    if j/939>0.15:
        to_drop.append(test.columns[i])
# Out:
# Year 0.0
# Field ID 0.0
# Field Area 0.0
# Day 1 0.0
# Day 2 0.0
# Day 3 0.0
# Day 4 0.0
# Day 5 0.0
# Day 6 0.0
# Day 7 0.0
# Day 8 0.0
# Day 9 0.0
# Day 10 0.0
# Day 11 0.0
# Day 12 0.0
# Day 13 0.0
# Day 14 0.0
# Day 15 0.0
# Day 16 0.0
# Day 17 0.0
# Day 18 0.0
# Day 19 0.0
# Day 20 0.0
# Day 21 0.0
# Day 22 0.0
# Day 23 0.0
# Day 24 0.0
# Day 25 0.0
# Day 26 0.0
# Day 27 0.0
# Day 28 0.0
# Day 29 0.0
# Day 30 0.0
# Day 31 0.0
# Day 32 0.0
# Day 33 0.0
# Day 34 0.0
# Day 35 0.0
# Day 36 0.0
# Day 37 0.0
# Day 38 0.0
# Day 39 0.0
# Day 40 0.0
# Day 41 0.0
# Day 42 0.0
# Day 43 0.0
# Day 44 0.0
# Day 45 0.0
# Day 46 0.0
# Day 47 0.0
# Day 48 0.0
# Day 49 0.0
# Day 50 0.0
# Day 51 0.0
# Day 52 0.0
# Day 53 0.0
# Day 54 0.0
# Day 55 0.0
# Day 56 0.0
# Day 57 0.0
# Day 58 0.0
# Day 59 0.0
# Day 60 0.0
# Day 61 0.0
# Day 62 0.0
# Day 63 0.0
# Day 64 0.0
# Day 65 0.0
# Day 66 0.0
# Day 67 0.0
# Day 68 0.0
# Day 69 0.0
# Day 70 0.0
# Day 71 0.0
# Day 72 0.0
# Day 73 0.0
# Day 74 0.0
# ...

# %%
del to_drop[0]

# %%
test.drop(to_drop,axis=1,inplace=True)

# %%
test
# Out:
#      Year  Field ID  Field Area   Day 1   Day 2   Day 3   Day 4   Day 5  \
# 0    2019       605      132.60 -0.0047 -0.0051 -0.0056 -0.0061 -0.0067
# 1    2019       305       61.44  0.2445  0.2438  0.2431  0.2424  0.2417
# 2    2019      1096       59.26  0.0145  0.0081  0.0018 -0.0046 -0.0110
# 3    2019       179      112.36 -0.0171 -0.0200 -0.0209 -0.0216 -0.0221
# 4    2019       282       68.57  0.3908  0.3892  0.3876  0.3859  0.3843
# ..    ...       ...         ...     ...     ...     ...     ...     ...
# 934  2019       665       46.50 -0.0176 -0.0179 -0.0181 -0.0184 -0.0186
# 935  2019      1277      229.24  0.0212  0.0181  0.0149  0.0118  0.0087
# 936  2019       875      166.97  0.0460  0.0411  0.0362  0.0312  0.0263
# 937  2019       301      123.52  0.2499  0.2483  0.2468  0.2452  0.2437
# 938  2019       464       88.15  0.3809  0.3599  0.3388  0.3178  0.2967
#
#       Day 6   Day 7  ...  Day 281  Day 282  Day 283  Day 284  Day 285  \
# ...

# %%
test.to_csv('data/test_dropped_290_with_nans.csv',index=False)

# %%
train.drop(to_drop,axis=1,inplace=True)

# %%
train.to_csv('data/train_dropped_290_with_nans.csv',index=False)

# %%
to_drop=[]
for i,j in enumerate(test.isna().sum()):
    print(list(test.columns)[i],j/939)
    if j/939>0.15:
        to_drop.append(str(i))
# Out:
# Year 0.0
# Field ID 0.0
# Field Area 0.0
# Day 1 0.0
# Day 2 0.0
# Day 3 0.0
# Day 4 0.0
# Day 5 0.0
# Day 6 0.0
# Day 7 0.0
# Day 8 0.0
# Day 9 0.0
# Day 10 0.0
# Day 11 0.0
# Day 12 0.0
# Day 13 0.0
# Day 14 0.0
# Day 15 0.0
# Day 16 0.0
# Day 17 0.0
# Day 18 0.0
# Day 19 0.0
# Day 20 0.0
# Day 21 0.0
# Day 22 0.0
# Day 23 0.0
# Day 24 0.0
# Day 25 0.0
# Day 26 0.0
# Day 27 0.0
# Day 28 0.0
# Day 29 0.0
# Day 30 0.0
# Day 31 0.0
# Day 32 0.0
# Day 33 0.0
# Day 34 0.0
# Day 35 0.0
# Day 36 0.0
# Day 37 0.0
# Day 38 0.0
# Day 39 0.0
# Day 40 0.0
# Day 41 0.0
# Day 42 0.0
# Day 43 0.0
# Day 44 0.0
# Day 45 0.0
# Day 46 0.0
# Day 47 0.0
# Day 48 0.0
# Day 49 0.0
# Day 50 0.0
# Day 51 0.0
# Day 52 0.0
# Day 53 0.0
# Day 54 0.0
# Day 55 0.0
# Day 56 0.0
# Day 57 0.0
# Day 58 0.0
# Day 59 0.0
# Day 60 0.0
# Day 61 0.0
# Day 62 0.0
# Day 63 0.0
# Day 64 0.0
# Day 65 0.0
# Day 66 0.0
# Day 67 0.0
# Day 68 0.0
# Day 69 0.0
# Day 70 0.0
# Day 71 0.0
# Day 72 0.0
# Day 73 0.0
# Day 74 0.0
# ...

# %%
train = pd.read_csv('data/X_train_imp.csv')
test = pd.read_csv('data/X_test_imp.csv')

print(train.shape, test.shape)
# Out:
# (2838, 368) (939, 368)

# %%
train
# Out:
#            0       1       2       3       4       5       6       7       8  \
# 0     2018.0   517.0   48.64  0.5369  0.5371  0.5375  0.5379  0.5384  0.5390
# 1     2019.0  1395.0   80.41  0.1159  0.1096  0.1034  0.0971  0.0909  0.0846
# 2     2017.0    44.0   43.64 -0.0204 -0.0207 -0.0210 -0.0212 -0.0215 -0.0218
# 3     2018.0  1591.0   79.34  0.4827  0.4576  0.4324  0.4073  0.3821  0.3570
# 4     2017.0   681.0  144.76 -0.0202 -0.0191 -0.0181 -0.0170 -0.0160 -0.0150
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 2833  2019.0  1631.0  117.04  0.4429  0.4430  0.4430  0.4431  0.4431  0.4431
# 2834  2016.0   336.0   70.61  0.0620  0.0687  0.0755  0.0822  0.0890  0.0957
# 2835  2016.0   371.0   60.26  0.0460  0.0399  0.0338  0.0277  0.0216  0.0154
# 2836  2017.0   115.0  237.86 -0.0148 -0.0149 -0.0150 -0.0151 -0.0153 -0.0154
# 2837  2018.0   215.0   48.86  0.2593  0.2590  0.2589  0.2588  0.2589  0.2590
#
# ...

# %%
del to_drop[0]

# %%
del to_drop[-1]

# %%
to_drop
# Out:
# ['293',
#  '294',
#  '295',
#  '296',
#  '297',
#  '298',
#  '299',
#  '300',
#  '301',
#  '302',
#  '303',
#  '304',
#  '305',
#  '306',
#  '307',
#  '308',
#  '309',
#  '310',
#  '311',
#  '312',
#  '313',
#  '314',
#  '315',
#  '316',
#  '317',
#  '318',
#  '319',
#  '320',
#  '321',
#  '322',
#  '323',
#  '324',
#  '325',
#  '326',
#  '327',
#  '328',
#  '329',
#  '330',
#  '331',
#  '332',
#  '333',
#  '334',
#  '335',
#  '336',
#  '337',
#  '338',
#  '339',
#  '340',
#  '341',
#  '342',
#  '343',
#  '344',
#  '345',
#  '346',
#  '347',
#  '348',
#  '349',
#  '350',
#  '351',
#  '352',
#  '353',
#  '354',
#  '355',
#  '356',
#  '357',
#  '358',
#  '359',
#  '360',
#  '361',
#  '362',
#  '363',
#  '364',
#  '365',
#  '366',
#  '367']

# %%
#test.drop(to_drop,axis=1,inplace=True)
test.to_csv('data/test_dropped_290_without_nans.csv',index=False)
#train.drop(to_drop,axis=1,inplace=True)
train.to_csv('data/train_dropped_290_without_nans.csv',index=False)

# %%
test
# Out:
#           0       1       2       3       4       5       6       7       8  \
# 0    2019.0   605.0  132.60 -0.0047 -0.0051 -0.0056 -0.0061 -0.0067 -0.0073
# 1    2019.0   305.0   61.44  0.2445  0.2438  0.2431  0.2424  0.2417  0.2410
# 2    2019.0  1096.0   59.26  0.0145  0.0081  0.0018 -0.0046 -0.0110 -0.0122
# 3    2019.0   179.0  112.36 -0.0171 -0.0200 -0.0209 -0.0216 -0.0221 -0.0223
# 4    2019.0   282.0   68.57  0.3908  0.3892  0.3876  0.3859  0.3843  0.3827
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 934  2019.0   665.0   46.50 -0.0176 -0.0179 -0.0181 -0.0184 -0.0186 -0.0188
# 935  2019.0  1277.0  229.24  0.0212  0.0181  0.0149  0.0118  0.0087  0.0056
# 936  2019.0   875.0  166.97  0.0460  0.0411  0.0362  0.0312  0.0263  0.0214
# 937  2019.0   301.0  123.52  0.2499  0.2483  0.2468  0.2452  0.2437  0.2422
# 938  2019.0   464.0   88.15  0.3809  0.3599  0.3388  0.3178  0.2967  0.2757
#
# ...
