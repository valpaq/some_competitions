# %%
import missingpy
import pandas as pd
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
# Out:
# c:\users\adm\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

print(train.shape, test.shape)
# Out:
# (2838, 370) (939, 369)

# %%
train
# Out:
#       Year  Field ID  Field Area   Day 1   Day 2   Day 3   Day 4   Day 5  \
# 0     2018       517       48.64  0.5369  0.5371  0.5375  0.5379  0.5384
# 1     2019      1395       80.41  0.1159  0.1096  0.1034  0.0971  0.0909
# 2     2017        44       43.64 -0.0204 -0.0207 -0.0210 -0.0212 -0.0215
# 3     2018      1591       79.34  0.4827  0.4576  0.4324  0.4073  0.3821
# 4     2017       681      144.76 -0.0202 -0.0191 -0.0181 -0.0170 -0.0160
# ...    ...       ...         ...     ...     ...     ...     ...     ...
# 2833  2019      1631      117.04  0.4429  0.4430  0.4430  0.4431  0.4431
# 2834  2016       336       70.61  0.0620  0.0687  0.0755  0.0822  0.0890
# 2835  2016       371       60.26  0.0460  0.0399  0.0338  0.0277  0.0216
# 2836  2017       115      237.86 -0.0148 -0.0149 -0.0150 -0.0151 -0.0153
# 2837  2018       215       48.86  0.2593  0.2590  0.2589  0.2588  0.2589
#
#        Day 6   Day 7  ...  Day 358  Day 359  Day 360  Day 361  Day 362  \
# ...

# %%
X_train = train.drop(['Culture','Day 366'], axis=1)
y_train = train['Culture']

X_test=test.drop(['Day 366'],axis=1)

# %%
print(X_train.shape, X_test.shape, y_train.shape)
# Out:
# (2838, 368) (939, 368) (2838,)

# %% [markdown]
# BaseLine

# %%
# %%time
X_train_imp = imputer.fit_transform(X_train,y=y_train)

# %%
X_test_imp = imputer.transform(X_test)
# Out:
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3

# %%
#X_train_imp['Culture']=train['Culture']
X_train_imp.to_csv('X_train_imp.csv',index=False)
X_test_imp.to_csv('X_test_imp.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-ee7724bf0147> in <module>
#       1 #X_train_imp['Culture']=train['Culture']
# ----> 2 X_train_imp.to_csv('X_train_imp.csv',index=False)
#       3 X_test_imp.to_csv('X_test_imp.csv',index=False)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_csv'
